# %% [markdown]
# <p>
# <font size='5' face='Georgia, Arial'>IIC2233 Apunte Programación Avanzada</font><br>
# <font size='1'> Creado por equipo Docente</font>
# </p>
#
#
# # Ejercicios propuestos: Webservices Client-side

# %% [markdown]
# Los siguientes problemas se proveen como oportunidad de ejercitar los conceptos revisados en el material de **_WebServices Client-side_**. Si tienes dudas sobre algún problema o alguna solución, no dudes en dejar una *issue* en el [foro del curso](https://github.com/IIC2233/syllabus/issue).

# %% [markdown]
# ### Ejercicio 1: Stats Pokemon

# %% [markdown]
# Queremos imprimir en consola los stats de tu pokemon favorito (en caso de no tener uno, será `Mew` cuyo id es 151) y luego investigar un poco más sobre sus habilidades. Para esto:
#
# 1. Lea la documentación de la siguiente API: https://pokeapi.co/docs/v2#pokemon
# 2. Haga una _requests_ al _endpoint_ correspondiente para obtener la información de su pokemon favorito
# 3. Utilice dicho resultado para imprimir un nuevo diccionario con el siguiente formato:
#
# ```json
# {
#     "nombre": ...,
#     "id": ...,
#     "peso":  ,
#     "movimiento": N (donde N es la cantidad de "moves" que tiene el pokemon),
#     "hp": X (donde X es el HP base del pokemon)
# }
# ```
#
# 4. Finalmente, en función del pokemon elegido, debes escoger una habilidad al azar de él (ver "abilities" del diccionario obtenido en (2)) y hacer otra _requests_ que permita obtener toda la información de dicha habilidad. Puedes revisar la documentación de dicho endpoint en este enlace: https://pokeapi.co/docs/v2#abilities.
# 5. Con la información obtenida en (4), deberás imprimir todos todos los nombres posibles de esa habilidad y luego cuantos pokemones tienen dicha habilidad.

# %%
NOMBRE_POKEMON = "Mew"

# %%
import requests
import random

# Completar

# %% [markdown]
# ### Ejercicio 2: _Fake News_

# %% [markdown]
# Aunque es incorrecto, queremos experimentar con la creación de una noticia falsa. Para esto, haremos lo siguiente:
#
# 1. Investigaremos una API para generar títulos de libros. Para esto revisar la siguiente documentación: https://fakerapi.it/en
# 2. Luego, deberás crear 3 libros y generar un texto como el siguiente: "¡Exito de ventas, los libros .... se venden en menos de 10 segundos!".
# 3. Inventa el título que sea lo más creativo posible.
# 4. Utilizar la siguiente API (https://jsonplaceholder.typicode.com/guide/) para crear un post con el título y texto inventado.
# 5. Finalmente, crea una issue en tu repositorio, **utilizando exclusivamente la api de Github** con el título creado en (3) y en el cuerpo poner el resultado de (4).

# %%
import requests

# Completar
