# %% [markdown]
# <p>
# <font size='5' face='Georgia, Arial'>IIC-2233 Apunte Programación Avanzada</font><br>
# <font size='1'> Ejercicios creados a partir de 2019-2 por Equipo Docente IIC2233. </font>
# <font size='1'> Actualizados en 2024-2</font>
# </p>
#
#
# # Ejercicios propuestos: Interfaces gráficas II
# ## PyQT QThreads

# %% [markdown]
# Los siguientes problemas se proveen como oportunidad de ejercitar los conceptos revisados en el material de interfaces gráficas I. Si tienes dudas sobre algún problema o alguna solución, no dudes en dejar una *issue* en el [foro del curso](https://github.com/IIC2233/syllabus/issues).

# %% [markdown]
# ### Ejercicio 1: Sigue el cuadrado 2

# %% [markdown]
# Crea una ventana de tamaño 500 por 500, que contenga un rectangulo de color verde dentro. Su posición inicial debe ser aleatoria y deberá tener las dimensiones: 50 por 50. Para crear el rectángulo, utiliza `QPixmap` y un `QLabel` dentro de la ventana.
#
# Agrega el siguiente comportamiento: si el usuario hace *click* dentro de la región que abarca el rectángulo verde, entonces su posición se mueve a una nueva posición aleatoria de forma gradual, como una animación. Si hace *click* fuera de la región abarcada por el rectángulo, no hay efecto. Utiliza `QThread` y **señales** para lograrlo.

# %% [markdown]
# Se muestra un ejemplo a continuación:
#
# ![](img/prob-3-2.png)

# %% [markdown]
# ### Ejercicio 2: Cronómetro
#
# Confecciona un cronómetro con `QThread`, que muestra cuantos minutos, segundos y milisegundos han ocurrido desde que se inicializó. Además, este cronómetro presenta 2 botones: `empezar` y `pausar`.
#
# * Cuando se presiona `empezar`, el cronómetro empieza a actualizar su tiempo, el cual lo hará cada medio segundos.
# * Cuando se presiona `pausar`, el cronómetro detiene su ejecución, pero no se reinicia. Si luego se oprime `empezar`, este continua desde el momento que estaba en último momento.
#
#
# Adicionalmente, tu ventana debe detectar una tecla (a elección tuya) el cual permite reiniciar el cronómetro. Es importante mencionar que este reinicio no detiene el cronómetro, es decir, solo vuelve su contador a `0:00:00`, pero en caso de estar ejecutándose, esta no se debe pausar.
